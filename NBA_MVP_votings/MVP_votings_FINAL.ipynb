# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Dependencies
import pandas as pd

# %%
#load csv
file = "Resources/mvp_votings.csv"
df_mvp = pd.read_csv(file)
df_mvp.head(10)
# Out:
#    Unnamed: 0   fga  fg3a   fta   per  ts_pct  usg_pct  bpm   season  \
# 0           0  18.6   0.2   6.5  25.1   0.572     28.4  8.0  1980-81
# 1           1  18.3   0.9   4.0  19.9   0.528     24.3  5.1  1980-81
# 2           2  18.2   0.0   6.9  25.5   0.616     26.3  5.3  1980-81
# 3           3  19.3   0.0  10.1  25.1   0.585     27.6  3.7  1980-81
# 4           4  21.1   0.4   7.6  22.9   0.555     32.3  1.6  1980-81
# 5           5  15.2   0.1   5.0  22.0   0.583     23.3  5.9  1980-81
# 6           6  14.2   0.0   4.8  25.2   0.579     27.1  5.0  1980-81
# 7           7  15.4   0.6   6.3  17.0   0.516     24.6  2.0  1980-81
# 8           8   9.6   0.1   5.2  14.3   0.582     17.5 -1.3  1980-81
# 9           9  18.5   0.2   4.1  18.0   0.556     24.5  0.8  1980-81
#
#                 player  ...  pts_per_g  trb_per_g  ast_per_g  stl_per_g  \
# 0        Julius Erving  ...       24.6        8.0        4.4        2.1
# 1           Larry Bird  ...       21.2       10.9        5.5        2.0
# 2  Kareem Abdul-Jabbar  ...       26.2       10.3        3.4        0.7
# 3         Moses Malone  ...       27.8       14.8        1.8        1.0
# 4        George Gervin  ...       27.1        5.1        3.2        1.1
# 5      Marques Johnson  ...       20.3        6.8        4.6        1.5
# 6        Robert Parish  ...       18.9        9.5        1.8        1.0
# 7       Dennis Johnson  ...       18.8        4.6        3.7        1.7
# 8       Tiny Archibald  ...       13.8        2.2        7.7        0.9
# 9        Jamaal Wilkes  ...       22.6        5.4        2.9        1.5
#
#    blk_per_g  fg_pct  fg3_pct  ft_pct    ws  ws_per_48
# 0        1.8   0.521    0.222   0.787  13.8      0.231
# 1        0.8   0.478    0.270   0.863  10.8      0.160
# 2        2.9   0.574    0.000   0.766  14.3      0.230
# 3        1.9   0.522    0.333   0.757  13.7      0.202
# 4        0.7   0.492    0.257   0.826  10.5      0.182
# 5        0.5   0.552    0.000   0.706  11.2      0.211
# 6        2.6   0.545    0.000   0.710  10.9      0.228
# 7        0.8   0.436    0.216   0.820   8.4      0.154
# 8        0.2   0.499    0.000   0.816   6.9      0.118
# 9        0.4   0.526    0.077   0.758   8.5      0.135
#
# [10 rows x 27 columns]

# %%
df_mvp.columns
# Out:
# Index(['Unnamed: 0', 'fga', 'fg3a', 'fta', 'per', 'ts_pct', 'usg_pct', 'bpm',
#        'season', 'player', 'win_pct', 'votes_first', 'points_won',
#        'points_max', 'award_share', 'g', 'mp_per_g', 'pts_per_g', 'trb_per_g',
#        'ast_per_g', 'stl_per_g', 'blk_per_g', 'fg_pct', 'fg3_pct', 'ft_pct',
#        'ws', 'ws_per_48'],
#       dtype='object')

# %%
mvp_points = df_mvp[df_mvp["season"] == "2017-18"][["player","votes_first", "points_won", "points_max", "award_share"]].copy()

# %%
mvp_points.rename(columns={"player":"Player", "votes_first":"Votes", "points_won":"Points_won","points_max":"Max_points",
                           "award_share":"Award_share"})
# Out:
#                     Player  Votes  Points_won  Max_points  Award_share
# 624           James Harden   86.0       965.0      1010.0        0.955
# 625           LeBron James   15.0       738.0      1010.0        0.731
# 626          Anthony Davis    0.0       445.0      1010.0        0.441
# 627         Damian Lillard    0.0       207.0      1010.0        0.205
# 628      Russell Westbrook    0.0        76.0      1010.0        0.075
# 629  Giannis Antetokounmpo    0.0        75.0      1010.0        0.074
# 630           Kevin Durant    0.0        66.0      1010.0        0.065
# 631          DeMar DeRozan    0.0        32.0      1010.0        0.032
# 632      LaMarcus Aldridge    0.0         6.0      1010.0        0.006
# 633           Jimmy Butler    0.0         5.0      1010.0        0.005
# 634          Stephen Curry    0.0         5.0      1010.0        0.005
# 635            Joel Embiid    0.0         4.0      1010.0        0.004
# 636         Victor Oladipo    0.0         2.0      1010.0        0.002
